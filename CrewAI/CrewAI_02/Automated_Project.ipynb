# %% [markdown]
# # Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
# result = crew.kickoff(
#   inputs=inputs
# )

import asyncio

# Recommended way in notebooks
result = await crew.kickoff_async(
    inputs=inputs
)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: ba82ead3-cbec-44d8-a763-8e2c90e446a4                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Carefully analyze the project_requirements for the Website project and break them down into individual   │
# │  tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are      │
# │  accounted for:                                                                                                 │
# │                                                                                                                 │
# │  - Create a responsive design that works well on desktop and mobile devices                                     │
# │  - Implement a modern, visually appealing user interface with a clean look                                      │
# │  - Develop a user-friendly navigation system with intuitive menu structure                                      │
# │  - Include an "About Us" page highlighting the company's history and values                                     │
# │  - Design a "Services" page showcasing the business's offerings with descriptions                               │
# │  - Create a "Contact Us" page with a form and integrated map for communication                                  │
# │  - Implement a blog section for sharing industry news and company updates                                       │
# │  - Ensure fast loading times and optimize for search engines (SEO)                                              │
# │  - Integrate social media links and sharing capabilities                                                        │
# │  - Include a testimonials section to showcase customer feedback and build trust                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │  ID: 521e2c0d-1c98-4d31-91ac-51f022d4a6f9                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Task: Carefully analyze the project_requirements for the Website project and break them down into individual   │
# │  tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are      │
# │  accounted for:                                                                                                 │
# │                                                                                                                 │
# │  - Create a responsive design that works well on desktop and mobile devices                                     │
# │  - Implement a modern, visually appealing user interface with a clean look                                      │
# │  - Develop a user-friendly navigation system with intuitive menu structure                                      │
# │  - Include an "About Us" page highlighting the company's history and values                                     │
# │  - Design a "Services" page showcasing the business's offerings with descriptions                               │
# │  - Create a "Contact Us" page with a form and integrated map for communication                                  │
# │  - Implement a blog section for sharing industry news and company updates                                       │
# │  - Ensure fast loading times and optimize for search engines (SEO)                                              │
# │  - Integrate social media links and sharing capabilities                                                        │
# │  - Include a testimonials section to showcase customer feedback and build trust                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ### Website Project Requirements Analysis and Actionable Task Breakdown                                        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Project Overview**: The goal of this project is to create a comprehensive, visually appealing, and           │
# │  user-friendly website for a small business. This website should be responsive, modern, and optimized for both  │
# │  user experience and search engines.                                                                            │
# │                                                                                                                 │
# │  **Team Members**:                                                                                              │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │  ### Comprehensive List of Tasks                                                                                │
# │                                                                                                                 │
# │  | Task ID | Task Description | Scope Details | Assigned To | Duration | Start Date | End Date | Dependencies   │
# │  | Deliverables |                                                                                               │
# │  |---------|------------------|----------------|-------------|----------|------------|----------|-------------  │
# │  ---|--------------|                                                                                            │
# │  | 1 | **Project Kickoff Meeting** | Hold a meeting to discuss project goals, timelines, and responsibilities   │
# │  | John Doe | 1 day | Day 1 | Day 1 | None | Meeting notes with action items |                                  │
# │  | 2 | **Gather Requirements** | Collect detailed project requirements from stakeholders | John Doe | 2 days |  │
# │  Day 2 | Day 3 | Task 1 | Requirements document |                                                               │
# │  | 3 | **Create Sitemap** | Outline the website structure and pages to be included | Bob Smith | 3 days | Day   │
# │  4 | Day 6 | Task 2 | Sitemap diagram |                                                                         │
# │  | 4 | **Design Wireframes** | Create rough mockups for each webpage | Bob Smith | 5 days | Day 7 | Day 11 |    │
# │  Task 3 | Wireframe images |                                                                                    │
# │  | 5 | **Responsive Design Creation** | Develop a responsive style guide for the site | Bob Smith | 5 days |    │
# │  Day 12 | Day 16 | Task 4 | Style guide document |                                                              │
# │  | 6 | **UI Design** | Design the visual components and overall layout | Bob Smith | 7 days | Day 17 | Day 23   │
# │  | Task 5 | Final UI mockup |                                                                                   │
# │  | 7 | **Navigation System Development** | Create a user-friendly menu structure | Jane Doe | 4 days | Day 24   │
# │  | Day 27 | Task 6 | Completed navigation structure |                                                           │
# │  | 8 | **Develop Content for "About Us" Page** | Write and format content detailing company history and values  │
# │  | Content Team | 3 days | Day 28 | Day 30 | Task 7 | About Us page content |                                   │
# │  | 9 | **Develop "Services" Page** | Showcase business offerings with descriptions | Content Team | 4 days |    │
# │  Day 31 | Day 34 | Task 7 | Services page content |                                                             │
# │  | 10 | **Create "Contact Us" Page** | Design page with a form and map integration | Jane Doe | 5 days | Day    │
# │  35 | Day 39 | Task 7 | Contact Us page |                                                                       │
# │  | 11 | **Blog Section Development** | Create section for industry news and company updates | Jane Doe | 6      │
# │  days | Day 40 | Day 45 | Task 7 | Blog architecture |                                                          │
# │  | 12 | **Performance Optimization** | Speed enhancements and SEO implementation | Jane Doe | 5 days | Day 46   │
# │  | Day 50 | Task 11 | Performance report |                                                                      │
# │  | 13 | **Social Media Integration** | Link and enable sharing on social platforms | Jane Doe | 3 days | Day    │
# │  51 | Day 53 | Task 12 | Social integration report |                                                            │
# │  | 14 | **Testimonials Section Creation** | Design and implement a customer feedback section | Jane Doe | 4     │
# │  days | Day 54 | Day 57 | Task 12 | Testimonials page |                                                         │
# │  | 15 | **Test Website Across Devices** | QA testing for functionality and responsiveness | Alice Johnson &     │
# │  Tom Brown | 7 days | Day 58 | Day 64 | Task 12 | Testing report |                                              │
# │  | 16 | **Fix Bugs/Issues** | Address issues found during testing | Jane Doe | 3 days | Day 65 | Day 67 | Task  │
# │  15 | Bug resolution log |                                                                                      │
# │  | 17 | **Final Review & Approval** | Present complete website to stakeholders for feedback | John Doe | 2      │
# │  days | Day 68 | Day 69 | Task 16 | Approval document |                                                         │
# │  | 18 | **Launch Website** | Deploy website to production server | Jane Doe | 1 day | Day 70 | Day 70 | Task    │
# │  17 | Launched website |                                                                                        │
# │                                                                                                                 │
# │  ### Gantt Chart Visualization                                                                                  │
# │                                                                                                                 │
# │  Below is a visual representation of the project timeline:                                                      │
# │                                                                                                                 │
# │  ```plaintext                                                                                                   │
# │  Task ID Task Description                       Start    Duration      End                                      │
# │  1      Project Kickoff Meeting                 Day 1    1 Day        Day 1                                     │
# │  2      Gather Requirements                      Day 2    2 Days       Day 3                                    │
# │  3      Create Sitemap                           Day 4    3 Days       Day 6                                    │
# │  4      Design Wireframes                        Day 7    5 Days       Day 11                                   │
# │  5      Responsive Design Creation               Day 12   5 Days       Day 16                                   │
# │  6      UI Design                                Day 17   7 Days       Day 23                                   │
# │  7      Navigation System Development            Day 24   4 Days       Day 27                                   │
# │  8      Develop Content for "About Us" Page     Day 28   3 Days       Day 30                                    │
# │  9      Develop "Services" Page                  Day 31   4 Days       Day 34                                   │
# │  10     Create "Contact Us" Page                 Day 35   5 Days       Day 39                                   │
# │  11     Blog Section Development                  Day 40   6 Days       Day 45                                  │
# │  12     Performance Optimization                  Day 46   5 Days       Day 50                                  │
# │  13     Social Media Integration                  Day 51   3 Days       Day 53                                  │
# │  14     Testimonials Section Creation              Day 54   4 Days       Day 57                                 │
# │  15     Test Website Across Devices               Day 58   7 Days       Day 64                                  │
# │  16     Fix Bugs/Issues                          Day 65   3 Days       Day 67                                   │
# │  17     Final Review & Approval                  Day 68   2 Days       Day 69                                   │
# │  18     Launch Website                            Day 70   1 Day        Day 70                                  │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  ### Key Deliverables Overview                                                                                  │
# │  1. Meeting notes from Kickoff                                                                                  │
# │  2. Detailed Requirements Document                                                                              │
# │  3. Sitemap Diagram                                                                                             │
# │  4. Wireframe Images                                                                                            │
# │  5. Style Guide Document                                                                                        │
# │  6. Final UI Mockup                                                                                             │
# │  7. Completed Navigation Structure                                                                              │
# │  8. Content for "About Us" and "Services" Pages                                                                 │
# │  9. Contact Us Page                                                                                             │
# │  10. Blog Architecture                                                                                          │
# │  11. Performance Report                                                                                         │
# │  12. Social Integration Report                                                                                  │
# │  13. Testimonials Page                                                                                          │
# │  14. Testing Report                                                                                             │
# │  15. Bug Resolution Log                                                                                         │
# │  16. Approval Document                                                                                          │
# │  17. Launched Website                                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Project Timeline**: This project is expected to take 70 days total, ensuring careful monitoring of the       │
# │  timeline and deliverables is critical for success. The project manager will provide ongoing updates and        │
# │  feedback during weekly team meetings.                                                                          │
# │                                                                                                                 │
# │  This breakdown serves as a foundation for successful execution, ensuring every aspect of the website is        │
# │  addressed and delivered efficiently.                                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Carefully analyze the project_requirements for the Website project and break them down into individual   │
# │  tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are      │
# │  accounted for:                                                                                                 │
# │                                                                                                                 │
# │  - Create a responsive design that works well on desktop and mobile devices                                     │
# │  - Implement a modern, visually appealing user interface with a clean look                                      │
# │  - Develop a user-friendly navigation system with intuitive menu structure                                      │
# │  - Include an "About Us" page highlighting the company's history and values                                     │
# │  - Design a "Services" page showcasing the business's offerings with descriptions                               │
# │  - Create a "Contact Us" page with a form and integrated map for communication                                  │
# │  - Implement a blog section for sharing industry news and company updates                                       │
# │  - Ensure fast loading times and optimize for search engines (SEO)                                              │
# │  - Integrate social media links and sharing capabilities                                                        │
# │  - Include a testimonials section to showcase customer feedback and build trust                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort         │
# │  required. Use historical data, task complexity, and available resources to provide a realistic estimation for  │
# │  each task.                                                                                                     │
# │                                                                                                                 │
# │  ID: 93719731-584d-4022-81de-3cc25cddbdda                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort         │
# │  required. Use historical data, task complexity, and available resources to provide a realistic estimation for  │
# │  each task.                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ### Detailed Estimation Report for Website Project                                                             │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Project Overview**: The aim of this project is to create a comprehensive website for a small business that   │
# │  is responsive, visually appealing, user-friendly, and SEO optimized. Below, you will find a detailed           │
# │  estimation of time, resources, and effort required for each task based on the provided breakdown and           │
# │  historical data.                                                                                               │
# │                                                                                                                 │
# │  ### Task Estimations                                                                                           │
# │                                                                                                                 │
# │  | Task ID | Task Description | Time Estimate (Days) | Resources Required | Effort Estimate (Hours) |           │
# │  Risks/Uncertainties |                                                                                          │
# │  |---------|------------------|----------------------|--------------------|-------------------------|---------  │
# │  ------------|                                                                                                  │
# │  | 1       | **Project Kickoff Meeting** | 1                    | 1 Project Manager  | 4                        │
# │  | Low - assumes no scheduling conflicts |                                                                      │
# │  | 2       | **Gather Requirements** | 2                    | 1 Project Manager  | 16                      |    │
# │  Medium - need clarity from all stakeholders |                                                                  │
# │  | 3       | **Create Sitemap** | 3                    | 1 Designer         | 24                      | Low -   │
# │  mostly straightforward |                                                                                       │
# │  | 4       | **Design Wireframes** | 5                    | 1 Designer         | 40                      |      │
# │  Medium - can depend on stakeholder feedback and revisions |                                                    │
# │  | 5       | **Responsive Design Creation** | 5                    | 1 Designer         | 40                    │
# │  | Medium - requires approval of wireframes |                                                                   │
# │  | 6       | **UI Design** | 7                    | 1 Designer         | 56                      | High -       │
# │  waiting for design feedback can delay progress |                                                               │
# │  | 7       | **Navigation System Development** | 4                    | 1 Software Engineer | 32                │
# │  | Medium - may need redesign if user testing reveals issues |                                                  │
# │  | 8       | **Develop Content for "About Us" Page** | 3                    | 2 Content Writers  | 24           │
# │  | Medium - availability of content team affects timing |                                                       │
# │  | 9       | **Develop "Services" Page** | 4                    | 2 Content Writers  | 32                       │
# │  | Medium - depends on stakeholder input for services offered |                                                 │
# │  | 10      | **Create "Contact Us" Page** | 5                    | 1 Software Engineer | 40                     │
# │  | Low - relative straightforward, but depends on design finalization |                                         │
# │  | 11      | **Blog Section Development** | 6                    | 1 Software Engineer | 48                     │
# │  | Medium - requires design approval and Content team availability |                                            │
# │  | 12      | **Performance Optimization** | 5                    | 1 Software Engineer | 40                     │
# │  | High - performance may vary based on existing content and structure |                                        │
# │  | 13      | **Social Media Integration** | 3                    | 1 Software Engineer | 24                     │
# │  | Low - integration is fairly standard |                                                                       │
# │  | 14      | **Testimonials Section Creation** | 4                    | 1 Software Engineer | 32                │
# │  | Medium - depends on approval of testimonial process |                                                        │
# │  | 15      | **Test Website Across Devices** | 7                    | 2 QA Engineers     | 56                   │
# │  | Medium - scope of testing may extend based on issues found |                                                 │
# │  | 16      | **Fix Bugs/Issues** | 3                    | 1 Software Engineer | 24                      |       │
# │  Medium - unforeseen bugs may arise during testing |                                                            │
# │  | 17      | **Final Review & Approval** | 2                    | 1 Project Manager  | 8                        │
# │  | Medium - may require additional iterations based on feedback |                                               │
# │  | 18      | **Launch Website** | 1                    | 1 Software Engineer | 8                       | Low -  │
# │  if all previous tasks are completed satisfactorily |                                                           │
# │                                                                                                                 │
# │  ### Summary of Estimates:                                                                                      │
# │  - **Total Time for Project**: 70 Days                                                                          │
# │  - **Total Effort Required**: 480 Hours                                                                         │
# │  - **Total Resources Required**: 2-3 staff members per task, varying by complexity                              │
# │                                                                                                                 │
# │  ### Risk Assessment                                                                                            │
# │  1. **Resource Availability**: Team members may have overlapping commitments which can lead to delays if not    │
# │  managed properly.                                                                                              │
# │  2. **Stakeholder Feedback**: Timely feedback is crucial. Delays in approvals can prolong the overall           │
# │  timeline.                                                                                                      │
# │  3. **Scope Creep**: Unplanned changes to project scope without proper assessments can lead to budget overruns  │
# │  and timeline extensions.                                                                                       │
# │  4. **Technological Constraints**: Any unforeseen issues with technology used can lead to performance issues    │
# │  and delays.                                                                                                    │
# │  5. **Testing Issues**: Complexity in the website functionalities can lead to longer testing periods than       │
# │  expected, which would shift timelines.                                                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  This detailed estimation report aims to bring clarity to the project execution plan by providing time,         │
# │  resources, and effort estimates while also addressing risks involved. By monitoring these estimates closely,   │
# │  we can mitigate risks and ensure the project stays within target timelines and budget.                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort         │
# │  required. Use historical data, task complexity, and available resources to provide a realistic estimation for  │
# │  each task.                                                                                                     │
# │                                                                                                                 │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Strategically allocate tasks for the Website project to team members based on their skills,              │
# │  availability, and current workload. Ensure that each task is assigned to the most suitable team member and     │
# │  that the workload is evenly distributed.                                                                       │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │  ID: 18f26644-49f0-4a22-97c5-b2ec854c6dc0                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │  Task: Strategically allocate tasks for the Website project to team members based on their skills,              │
# │  availability, and current workload. Ensure that each task is assigned to the most suitable team member and     │
# │  that the workload is evenly distributed.                                                                       │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  tasks=[TaskEstimate(task_name='Project Kickoff Meeting', estimated_time_hours=4.0, required_resources=['John   │
# │  Doe']), TaskEstimate(task_name='Gather Requirements', estimated_time_hours=16.0, required_resources=['John     │
# │  Doe']), TaskEstimate(task_name='Create Sitemap', estimated_time_hours=24.0, required_resources=['Bob           │
# │  Smith']), TaskEstimate(task_name='Design Wireframes', estimated_time_hours=40.0, required_resources=['Bob      │
# │  Smith']), TaskEstimate(task_name='Responsive Design Creation', estimated_time_hours=40.0,                      │
# │  required_resources=['Bob Smith']), TaskEstimate(task_name='UI Design', estimated_time_hours=56.0,              │
# │  required_resources=['Bob Smith']), TaskEstimate(task_name='Navigation System Development',                     │
# │  estimated_time_hours=32.0, required_resources=['Jane Doe']), TaskEstimate(task_name="Develop Content for       │
# │  'About Us' Page", estimated_time_hours=24.0, required_resources=['Content Team']),                             │
# │  TaskEstimate(task_name="Develop 'Services' Page", estimated_time_hours=32.0, required_resources=['Content      │
# │  Team']), TaskEstimate(task_name="Create 'Contact Us' Page", estimated_time_hours=40.0,                         │
# │  required_resources=['Jane Doe']), TaskEstimate(task_name='Blog Section Development',                           │
# │  estimated_time_hours=48.0, required_resources=['Jane Doe']), TaskEstimate(task_name='Performance               │
# │  Optimization', estimated_time_hours=40.0, required_resources=['Jane Doe']), TaskEstimate(task_name='Social     │
# │  Media Integration', estimated_time_hours=24.0, required_resources=['Jane Doe']),                               │
# │  TaskEstimate(task_name='Testimonials Section Creation', estimated_time_hours=32.0, required_resources=['Jane   │
# │  Doe']), TaskEstimate(task_name='Test Website Across Devices', estimated_time_hours=56.0,                       │
# │  required_resources=['Alice Johnson', 'Tom Brown']), TaskEstimate(task_name='Fix Bugs/Issues',                  │
# │  estimated_time_hours=24.0, required_resources=['Jane Doe']), TaskEstimate(task_name='Final Review &            │
# │  Approval', estimated_time_hours=8.0, required_resources=['John Doe']), TaskEstimate(task_name='Launch          │
# │  Website', estimated_time_hours=8.0, required_resources=['Jane Doe'])]                                          │
# │  milestones=[Milestone(milestone_name='Kickoff Phase', tasks=['1', '2']), Milestone(milestone_name='Design      │
# │  Phase', tasks=['3', '4', '5', '6']), Milestone(milestone_name='Development Phase', tasks=['7', '8', '9',       │
# │  '10', '11', '12', '13', '14']), Milestone(milestone_name='Testing Phase', tasks=['15', '16']),                 │
# │  Milestone(milestone_name='Finalization Phase', tasks=['17', '18'])]                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Strategically allocate tasks for the Website project to team members based on their skills,              │
# │  availability, and current workload. Ensure that each task is assigned to the most suitable team member and     │
# │  that the workload is evenly distributed.                                                                       │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: ba82ead3-cbec-44d8-a763-8e2c90e446a4                                                                       │
# │  Final Output: {"tasks":[{"task_name":"Project Kickoff                                                          │
# │  Meeting","estimated_time_hours":4.0,"required_resources":["John Doe"]},{"task_name":"Gather                    │
# │  Requirements","estimated_time_hours":16.0,"required_resources":["John Doe"]},{"task_name":"Create              │
# │  Sitemap","estimated_time_hours":24.0,"required_resources":["Bob Smith"]},{"task_name":"Design                  │
# │  Wireframes","estimated_time_hours":40.0,"required_resources":["Bob Smith"]},{"task_name":"Responsive Design    │
# │  Creation","estimated_time_hours":40.0,"required_resources":["Bob Smith"]},{"task_name":"UI                     │
# │  Design","estimated_time_hours":56.0,"required_resources":["Bob Smith"]},{"task_name":"Navigation System        │
# │  Development","estimated_time_hours":32.0,"required_resources":["Jane Doe"]},{"task_name":"Develop Content for  │
# │  'About Us' Page","estimated_time_hours":24.0,"required_resources":["Content Team"]},{"task_name":"Develop      │
# │  'Services' Page","estimated_time_hours":32.0,"required_resources":["Content Team"]},{"task_name":"Create       │
# │  'Contact Us' Page","estimated_time_hours":40.0,"required_resources":["Jane Doe"]},{"task_name":"Blog Section   │
# │  Development","estimated_time_hours":48.0,"required_resources":["Jane Doe"]},{"task_name":"Performance          │
# │  Optimization","estimated_time_hours":40.0,"required_resources":["Jane Doe"]},{"task_name":"Social Media        │
# │  Integration","estimated_time_hours":24.0,"required_resources":["Jane Doe"]},{"task_name":"Testimonials         │
# │  Section Creation","estimated_time_hours":32.0,"required_resources":["Jane Doe"]},{"task_name":"Test Website    │
# │  Across Devices","estimated_time_hours":56.0,"required_resources":["Alice Johnson","Tom                         │
# │  Brown"]},{"task_name":"Fix Bugs/Issues","estimated_time_hours":24.0,"required_resources":["Jane                │
# │  Doe"]},{"task_name":"Final Review & Approval","estimated_time_hours":8.0,"required_resources":["John           │
# │  Doe"]},{"task_name":"Launch Website","estimated_time_hours":8.0,"required_resources":["Jane                    │
# │  Doe"]}],"milestones":[{"milestone_name":"Kickoff Phase","tasks":["1","2"]},{"milestone_name":"Design           │
# │  Phase","tasks":["3","4","5","6"]},{"milestone_name":"Development                                               │
# │  Phase","tasks":["7","8","9","10","11","12","13","14"]},{"milestone_name":"Testing                              │
# │  Phase","tasks":["15","16"]},{"milestone_name":"Finalization Phase","tasks":["17","18"]}]}                      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0013
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0          8760           5495                     0               3265
#
#    reasoning_tokens  cache_creation_tokens  successful_requests
# 0                 0                      0                    3

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Project Kickoff Meeting',
#    'estimated_time_hours': 4.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Gather Requirements',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Create Sitemap',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Design Wireframes',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Responsive Design Creation',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'UI Design',
#    'estimated_time_hours': 56.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Navigation System Development',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': "Develop Content for 'About Us' Page",
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Content Team']},
#   {'task_name': "Develop 'Services' Page",
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Content Team']},
#   {'task_name': "Create 'Contact Us' Page",
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Blog Section Development',
#    'estimated_time_hours': 48.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Performance Optimization',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Social Media Integration',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Testimonials Section Creation',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Test Website Across Devices',
#    'estimated_time_hours': 56.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Fix Bugs/Issues',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Final Review & Approval',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Launch Website',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['Jane Doe']}],
#  'milestones': [{'milestone_name': 'Kickoff Phase', 'tasks': ['1', '2']},
#   {'milestone_name': 'Design Phase', 'tasks': ['3', '4', '5', '6']},
#   {'milestone_name': 'Development Phase',
#    'tasks': ['7', '8', '9', '10', '11', '12', '13', '14']},
#   {'milestone_name': 'Testing Phase', 'tasks': ['15', '16']},
#   {'milestone_name': 'Finalization Phase', 'tasks': ['17', '18']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_e7d77 th {
#   font-size: 120%;
# }
# #T_e7d77  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_e7d77" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7d77_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_e7d77_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_e7d77_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7d77_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7d77_row0_col0" class="data row0 col0" >Project Kickoff Meeting</td>
#       <td id="T_e7d77_row0_col1" class="data row0 col1" >4.000000</td>
#       <td id="T_e7d77_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7d77_row1_col0" class="data row1 col0" >Gather Requirements</td>
#       <td id="T_e7d77_row1_col1" class="data row1 col1" >16.000000</td>
#       <td id="T_e7d77_row1_col2" class="data row1 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e7d77_row2_col0" class="data row2 col0" >Create Sitemap</td>
#       <td id="T_e7d77_row2_col1" class="data row2 col1" >24.000000</td>
#       <td id="T_e7d77_row2_col2" class="data row2 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e7d77_row3_col0" class="data row3 col0" >Design Wireframes</td>
#       <td id="T_e7d77_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_e7d77_row3_col2" class="data row3 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e7d77_row4_col0" class="data row4 col0" >Responsive Design Creation</td>
#       <td id="T_e7d77_row4_col1" class="data row4 col1" >40.000000</td>
#       <td id="T_e7d77_row4_col2" class="data row4 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e7d77_row5_col0" class="data row5 col0" >UI Design</td>
#       <td id="T_e7d77_row5_col1" class="data row5 col1" >56.000000</td>
#       <td id="T_e7d77_row5_col2" class="data row5 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e7d77_row6_col0" class="data row6 col0" >Navigation System Development</td>
#       <td id="T_e7d77_row6_col1" class="data row6 col1" >32.000000</td>
#       <td id="T_e7d77_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e7d77_row7_col0" class="data row7 col0" >Develop Content for 'About Us' Page</td>
#       <td id="T_e7d77_row7_col1" class="data row7 col1" >24.000000</td>
#       <td id="T_e7d77_row7_col2" class="data row7 col2" >['Content Team']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e7d77_row8_col0" class="data row8 col0" >Develop 'Services' Page</td>
#       <td id="T_e7d77_row8_col1" class="data row8 col1" >32.000000</td>
#       <td id="T_e7d77_row8_col2" class="data row8 col2" >['Content Team']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e7d77_row9_col0" class="data row9 col0" >Create 'Contact Us' Page</td>
#       <td id="T_e7d77_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_e7d77_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e7d77_row10_col0" class="data row10 col0" >Blog Section Development</td>
#       <td id="T_e7d77_row10_col1" class="data row10 col1" >48.000000</td>
#       <td id="T_e7d77_row10_col2" class="data row10 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e7d77_row11_col0" class="data row11 col0" >Performance Optimization</td>
#       <td id="T_e7d77_row11_col1" class="data row11 col1" >40.000000</td>
#       <td id="T_e7d77_row11_col2" class="data row11 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e7d77_row12_col0" class="data row12 col0" >Social Media Integration</td>
#       <td id="T_e7d77_row12_col1" class="data row12 col1" >24.000000</td>
#       <td id="T_e7d77_row12_col2" class="data row12 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e7d77_row13_col0" class="data row13 col0" >Testimonials Section Creation</td>
#       <td id="T_e7d77_row13_col1" class="data row13 col1" >32.000000</td>
#       <td id="T_e7d77_row13_col2" class="data row13 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e7d77_row14_col0" class="data row14 col0" >Test Website Across Devices</td>
#       <td id="T_e7d77_row14_col1" class="data row14 col1" >56.000000</td>
#       <td id="T_e7d77_row14_col2" class="data row14 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e7d77_row15_col0" class="data row15 col0" >Fix Bugs/Issues</td>
#       <td id="T_e7d77_row15_col1" class="data row15 col1" >24.000000</td>
#       <td id="T_e7d77_row15_col2" class="data row15 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e7d77_row16_col0" class="data row16 col0" >Final Review & Approval</td>
#       <td id="T_e7d77_row16_col1" class="data row16 col1" >8.000000</td>
#       <td id="T_e7d77_row16_col2" class="data row16 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e7d77_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e7d77_row17_col0" class="data row17 col0" >Launch Website</td>
#       <td id="T_e7d77_row17_col1" class="data row17 col1" >8.000000</td>
#       <td id="T_e7d77_row17_col2" class="data row17 col2" >['Jane Doe']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_29398 th {
#   font-size: 120%;
# }
# #T_29398  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_29398" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29398_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_29398_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29398_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29398_row0_col0" class="data row0 col0" >Kickoff Phase</td>
#       <td id="T_29398_row0_col1" class="data row0 col1" >['1', '2']</td>
#     </tr>
#     <tr>
#       <th id="T_29398_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_29398_row1_col0" class="data row1 col0" >Design Phase</td>
#       <td id="T_29398_row1_col1" class="data row1 col1" >['3', '4', '5', '6']</td>
#     </tr>
#     <tr>
#       <th id="T_29398_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_29398_row2_col0" class="data row2 col0" >Development Phase</td>
#       <td id="T_29398_row2_col1" class="data row2 col1" >['7', '8', '9', '10', '11', '12', '13', '14']</td>
#     </tr>
#     <tr>
#       <th id="T_29398_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_29398_row3_col0" class="data row3 col0" >Testing Phase</td>
#       <td id="T_29398_row3_col1" class="data row3 col1" >['15', '16']</td>
#     </tr>
#     <tr>
#       <th id="T_29398_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_29398_row4_col0" class="data row4 col0" >Finalization Phase</td>
#       <td id="T_29398_row4_col1" class="data row4 col1" >['17', '18']</td>
#     </tr>
#   </tbody>
# </table>
